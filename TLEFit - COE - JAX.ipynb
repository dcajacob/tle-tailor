# %%
# %config Completer.use_jedi = False

# %%
import matplotlib.pyplot as plt

# %%
from tlefit_coe_jax import *
# Out:
# WARNING:jax._src.lib.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
import numpy as np

# %%
line1 = '1 25544U 98067A   14020.93268519  .00009878  00000-0  18200-3 0  5082'
line2 = '2 25544  51.6498 109.4756 0003572  55.9686 274.8005 15.49815350868473'
satellite = EarthSatellite(line1, line2, 'ISS (ZARYA)', ts)

line1 = '1 40019U 14033K   21064.48089419  .00000027  00000-0  13123-4 0  9994'
line2 = '2 40019  97.7274 245.3630 0083155 314.3836  45.0579 14.67086574359033'
satellite = EarthSatellite(line1, line2, 'APRIZESAT 10', ts)

# %%
fit_method = test_tle_fit_normalized
# fit_method = test_tle_fit

iterations, sigma, sigmas, dxs, bs, lamdas, b_epoch, b_new_epoch, b, P, A = fit_method(satellite, lamda=1e-3, rms_epsilon=0.0001, debug=True)
# Out:
# Initial semi-major axis (a) = 7054.852 km
# COE elements (original) = [7048.523352797561, 0.0083155, 1.7056648994135064, 4.282392212570847, 5.487028934272845, 0.786408709034353, 1.3123000000000001e-05]
# Residuals at epoch time [ 5.60046126e-01 -3.55208784e+00 -1.46641965e+01 -2.73377804e-03
#  -7.52656544e-03  1.66212876e-04]
# Residual magnitudes at epoch time 15.0987, 0.00800939
#
#
# #################### ITERATION 1 ####################
#
# Condition number (A): 50095.081
# Condition number (ATWA_acc): 13543803.64408722
# Lambda:  0.001
# Residuals after/before 196 < 8.2e+06
# Covariance a: 12.323 m
# dx  [-6.32427946e+00  2.91129898e-04  8.86588005e-05  1.50245701e-06
#  -1.39220109e-01  1.39216623e-01 -8.27898944e-04]
# COE elements = [ 7.04852725e+03  8.25455910e-03  1.70566489e+00  4.28239372e+00
#   5.48210981e+00  7.91329584e-01 -8.26898944e-04]
#
# Current Solution 7048.52725359321 0.0082546 97.7274 245.3631 314.1018 45.3398 -8.2690e-04
#         Original 7048.523352797561 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
# Residual (b) = [-7.14673731e-01  3.11148753e+00  1.46442084e+01  2.40917232e-03
#   7.13957301e-03  8.32241505e-04]
# Residuals (b) r = 15, v = 0.00758
# Convergence test: 0.998346, sigma_new(82.7) < sigma_old(5e+04)
#
# #################### ITERATION 2 ####################
#
# Condition number (A): 52688.495
# Condition number (ATWA_acc): 13460677.647120733
# Lambda:  0.001
# Residuals after/before 0.00341 < 196
# Covariance a: 12.306 m
# dx  [-3.89747238e-03  6.07801641e-05  1.03595921e-08 -1.50098852e-06
#   4.95057397e-03 -4.95231764e-03  8.39971132e-04]
# COE elements = [7.04852336e+03 8.31533927e-03 1.70566490e+00 4.28239221e+00
#  5.48706038e+00 7.86377266e-01 1.30721882e-05]
#
# Current Solution 7048.523356120826 0.0083153 97.7274 245.3630 314.3854 45.0561 +1.3072e-05
#         Original 7048.523352797561 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
# Residual (b) = [ 1.80849849e-01  4.73284718e-01  1.65062797e-01 -5.61274612e-05
#   5.84284210e-05  5.49490803e-04]
# Residuals (b) r = 0.533, v = 0.000555
# Convergence test: 0.995116, sigma_new(0.404) < sigma_old(82.7)
#
# #################### ITERATION 3 ####################
#
# Condition number (A): 52604.441
# Condition number (ATWA_acc): 13456143.993964372
# Lambda:  0.001
# Residuals after/before 3.36e-09 < 0.00341
# Covariance a: 12.304 m
# dx  [-3.31994956e-06  1.60570309e-07  6.54888081e-12 -1.47485126e-09
#  -3.14145371e-05  3.14123509e-05  5.07615134e-08]
# COE elements = [7.04852335e+03 8.31549984e-03 1.70566490e+00 4.28239221e+00
#  5.48702897e+00 7.86408678e-01 1.31229497e-05]
#
# Current Solution 7048.523352800877 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
#         Original 7048.523352797561 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
# Residual (b) = [-8.00064704e-04 -3.58253555e-04  4.17990680e-03  9.96707508e-07
#   2.09324536e-06 -2.51753382e-07]
# Residuals (b) r = 0.00427, v = 2.33e-06
# Convergence test: 0.995822, sigma_new(0.00169) < sigma_old(0.404)
#
# #################### ITERATION 4 ####################
#
# Condition number (A): 52605.026
# Condition number (ATWA_acc): 13456142.267325355
# Lambda:  0.001
# Residuals after/before 3.35e-15 < 3.36e-09
# Covariance a: 12.304 m
# dx  [-3.31465667e-09  1.64514835e-10  6.43527917e-15 -1.47288603e-12
#  -3.07760699e-08  3.07738762e-08  5.05440578e-11]
# COE elements = [7.04852335e+03 8.31550000e-03 1.70566490e+00 4.28239221e+00
#  5.48702893e+00 7.86408709e-01 1.31230003e-05]
#
# Current Solution 7048.5233527975615 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
#         Original 7048.523352797561 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
# Residual (b) = [-7.78604317e-07 -3.16637852e-07  4.16414787e-06  9.85177495e-10
#   2.08363116e-09 -2.04010142e-10]
# Residuals (b) r = 4.25e-06, v = 2.31e-09
# Convergence test: 0.999008, sigma_new(1.67e-06) < sigma_old(0.00169)
#
# Stopped due to dx convergence
#
# #################### SOLUTION IN 4 ITERATIONS ####################
#
# Solution 7048.5233527975615 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
# Original 7048.523352797561 0.0083155 97.7274 245.3630 314.3836 45.0579 +1.3123e-05
# Residuals (b) r = 4.25e-06, v = 2.31e-09
# Stopped in 4 iterations
# Residual at epoch     1.510e+01 km 8.009e-03 km/s
# Residual at new epoch 4.209e-06 km 0.000e+00 km/s
# Residual at the end   4.248e-06 km 2.314e-09 km/s

# %%
plt.semilogy(range(len(sigmas)), sigmas)

# %%
plt.semilogy(bs)

# %%
ls tles/*.txt
# Out:
# tles/22335.txt    tles/boom.txt         tles/gps-ops.txt  tles/spire.txt
# tles/active.txt   tles/cubesat.txt      tles/planet.txt   tles/stations.txt
# tles/analyst.txt  tles/engineering.txt  tles/ses.txt

# %%
tle_filename = 'tles/TWOLINE.TXT'
tle_filename = 'tles/22335.txt'

# %%
# !head $tle_filename
# Out:
# 0 VANGUARD 1
# 1 00005U 58002B   22334.74432056  .00000101  00000-0  15418-3 0  9999
# 2 00005  34.2490 346.9265 1845722  66.0949 312.1720 10.85038156302601
# 0 VANGUARD 1
# 1 00005U 58002B   22335.11262076  .00000100  00000-0  15292-3 0  9993
# 2 00005  34.2490 345.7915 1845718  67.7532 310.8033 10.85038245302646
# 0 VANGUARD 2
# 1    11U 59001A   22335.21011001  .00000606  00000-0  30430-3 0  9993
# 2    11  32.8791 287.3922 1465359 275.6560  67.9281 11.86232147723203
# 0 VANGUARD 2

# %%
with open(tle_filename, 'r') as f:
    
    tle_lines = f.readlines()
    
    tles = []
    
    for cnt, ix in enumerate(range(0, len(tle_lines), 3)):
        #print(cnt, ix, tle_lines[ix])
        tles.append((tle_lines[ix].strip(), tle_lines[ix + 1].strip(), tle_lines[ix + 2].strip()))

# %%
if tle_filename == 'tles/TWOLINE.TXT':
    with open(tle_filename, 'r') as f:

        tle_lines = f.readlines()

        tles = []
        tle = []

        for line in tle_lines:
            if line.startswith('#'):
                continue
                
            tle.append(line.strip())
            
            if line.startswith('2 '):
                tles.append((tle[0][2:9], tle[0], tle[1]))
                tle = []

# %%
tles[:3]
# Out:
# [('0 VANGUARD 1',
#   '1 00005U 58002B   22334.74432056  .00000101  00000-0  15418-3 0  9999',
#   '2 00005  34.2490 346.9265 1845722  66.0949 312.1720 10.85038156302601'),
#  ('0 VANGUARD 1',
#   '1 00005U 58002B   22335.11262076  .00000100  00000-0  15292-3 0  9993',
#   '2 00005  34.2490 345.7915 1845718  67.7532 310.8033 10.85038245302646'),
#  ('0 VANGUARD 2',
#   '1    11U 59001A   22335.21011001  .00000606  00000-0  30430-3 0  9993',
#   '2    11  32.8791 287.3922 1465359 275.6560  67.9281 11.86232147723203')]

# %%
# LM Test

limit = 100#9*1000000
failed_tles = []

print(f'{"TLE":24s} {"Iter":>5s} {"Cov (m)":>10s}   {"StdDev (m)":>10s}   {"Res @ Epoch (m)":>13s}   {"Res @ End (m)":>13s}')

for idx, tle in enumerate(tles):

    line1 = tle[1]
    line2 = tle[2]
    satellite = EarthSatellite(line1, line2, tle[0], ts)
    
    try:
        iterations, sigma, sigmas, dxs, bs, lamdas, b_epoch, b_new_epoch, b, P, A = fit_method(satellite, fit_span=1, max_iter=25, lamda=1e-3, rms_epsilon=0.0001, debug=False)
        
        print(f'{tle[0]:24s} {iterations:5d} {np.sqrt(np.diag(P)[0]) * 1000:10.3f} {sigma * 1000:12.2e} {np.linalg.norm(b_new_epoch[0:3]) * 1000:17.2e} {np.linalg.norm(b[0:3]) * 1000:15.2e}')
    except:
        print(f'{tle[0]:24s} Failed')
    
    if idx == limit:
        break
# Out:
# TLE                       Iter    Cov (m)   StdDev (m)   Res @ Epoch (m)   Res @ End (m)
# 0 VANGUARD 1                 4 1172945.940     5.34e-08          1.29e-08        2.19e-08
# 0 THOR ABLESTAR DEB          4 903783.812     1.86e-06          4.62e-06        4.70e-06
# 0 THOR ABLESTAR DEB          4 933750.581     2.65e-06          6.56e-06        6.68e-06
# 0 THOR ABLESTAR DEB          4 934507.808     2.65e-06          6.57e-06        6.67e-06
# 0 THOR ABLESTAR DEB          4 935497.066     2.66e-06          6.58e-06        6.66e-06
# 0 THOR ABLESTAR DEB          4 1050806.382     4.41e-07          1.16e-06        1.14e-06
# 0 THOR ABLESTAR DEB          4 1048487.947     3.99e-07          1.06e-06        1.04e-06
# 0 THOR ABLESTAR DEB          4 1048487.947     3.99e-07          1.06e-06        1.04e-06
# 0 THOR ABLESTAR DEB          4 1112602.683     1.26e-06          2.51e-06        2.61e-06
# 0 THOR ABLESTAR DEB          4 1113025.881     1.22e-06          2.40e-06        2.51e-06
# 0 THOR ABLESTAR DEB          4 1113025.881     1.22e-06          2.40e-06        2.51e-06
# 0 THOR ABLESTAR DEB          4 1006321.478     4.63e-06          1.12e-05        1.14e-05
# 0 THOR ABLESTAR DEB          4 1006802.484     4.53e-06          1.10e-05        1.12e-05
# 0 THOR ABLESTAR DEB          4 1006802.484     4.53e-06          1.10e-05        1.12e-05
# 0 THOR ABLESTAR DEB          4 1063653.139     2.90e-07          5.92e-07        6.20e-07
# 0 THOR ABLESTAR DEB          4 1064018.802     3.07e-07          6.25e-07        6.64e-07
# 0 THOR ABLESTAR DEB          4 920557.505     7.91e-06          2.00e-05        2.02e-05
# 0 THOR ABLESTAR DEB          4 921530.589     8.06e-06          2.04e-05        2.06e-05
# 0 THOR ABLESTAR DEB          4 921530.589     8.06e-06          2.04e-05        2.06e-05
# 0 THOR ABLESTAR DEB          4 1028625.005     1.23e-06          2.93e-06        3.00e-06
# 0 THOR ABLESTAR DEB          4 1028404.854     1.37e-06          3.27e-06        3.34e-06
# 0 THOR ABLESTAR DEB          4 1028283.450     1.45e-06          3.45e-06        3.53e-06
# 0 THOR ABLESTAR DEB          4 915814.062     9.47e-06          2.07e-05        2.13e-05
# 0 THOR ABLESTAR DEB          4 915767.296     9.44e-06          2.07e-05        2.13e-05
# 0 THOR ABLESTAR DEB          4 1010707.446     1.90e-05          4.95e-05        4.92e-05
# 0 THOR ABLESTAR DEB          4 895425.279     5.74e-06          1.29e-05        1.32e-05
# 0 THOR ABLESTAR DEB          4 895346.989     5.61e-06          1.26e-05        1.29e-05
# 0 THOR ABLESTAR DEB          4 895346.989     5.61e-06          1.26e-05        1.29e-05
# 0 THOR ABLESTAR DEB          4 1055305.981     3.77e-06          9.50e-06        9.60e-06
# 0 THOR ABLESTAR DEB          4 1054449.375     3.65e-06          9.19e-06        9.29e-06
# 0 THOR ABLESTAR DEB          4 1054104.820     3.60e-06          9.08e-06        9.17e-06
# 0 THOR ABLESTAR DEB          4 1095531.182     1.89e-07          4.69e-07        4.57e-07
# 0 THOR ABLESTAR DEB          4 1108716.680     4.95e-06          1.24e-05        1.26e-05
# 0 THOR ABLESTAR DEB          4 1108568.571     4.95e-06          1.24e-05        1.26e-05
