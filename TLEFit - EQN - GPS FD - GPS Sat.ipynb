# %%
# %config Completer.use_jedi = False

# %%
import sys

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tlefit_equinoctial_eph_fd import *

# %%
import coord_skyfield
from coord_skyfield import ITRF2TEME

# %%
df = pd.read_feather('ephemeris/gpsd6n22short.fth')

t = df.timestamp
ephemeris = [((row['x'], row['y'], row['z']), (row['xdot'], row['ydot'], row['zdot'])) for idx, row in df.iterrows()]

ephemeris_teme = ITRF2TEME(t, ephemeris)
ephemeris = ephemeris_teme
t = np.array([_t.to_pydatetime() for _t in t])
# Out:
# /tmp/ipykernel_826628/2830078750.py:8: UserWarning: Discarding nonzero nanoseconds in conversion.
#   t = np.array([_t.to_pydatetime() for _t in t])

# %%
last_obs = 300
obs_stride = 1
lamda = 1e-3 * 0 + 1 # Interesting.The smaller number works, but diverges. This is better
iterations, solve_sat, elements_coe, sigma, sigmas, dxs, bs, lamdas, b_epoch, b_new_epoch, b, P, A = \
test_tle_fit_normalized_equinoctial(t, ephemeris, central_diff=True, last_obs=last_obs, obs_stride=obs_stride, lamda=lamda, rms_epsilon=0.0001, debug=True)
# Out:
# Initial semi-major axis (a) = 26558.668 km
# COE elements (original) = [26558.66821181454, 0.004955996580964593, 0.9534815917054646, 5.5866081275021084, 4.608844240039538, 0.09615470379843861, 1e-06]
# Residuals at epoch time [-1.15872338e+01 -1.88040707e+00 -6.43374342e-01 -6.90100427e-04
#   6.81057778e-04 -1.47135401e-03]
# Residual magnitudes at epoch time 11.7564, 0.00176209
#
#
# #################### ITERATION 1 ####################
#
# Condition number (A): 88.984
# Condition number (ATWA_acc): 248580326496728.1
# Lambda:  0.1
# Residuals after/before 2.56e+04 < 6.88e+09
# Covariance a: 0.034 m
# dx  [ 1.73695617e+00 -1.69568580e-04 -2.25813922e-04  1.89943210e-04
#  -2.19749692e-04  2.79962368e-05 -1.34090463e-01]
# COE elements = [26560.405167980836, 0.005235142290253865, 0.9537381165740815, 5.586316636743829, 4.617518301381834, 0.08796207642409204, -0.13408946323670282]
# EQN elements = (26560.405167980836, -0.00372520386262617, -0.003678256513768384, 4.008611707370168, -0.33158822536864135, 0.3961866137808042, -0.13408946323670282)
# Residual (b) = [ 1.09155863e+01  2.53668061e+00 -5.53713248e-01  7.69550083e-04
#  -7.70229194e-04  1.20066612e-03]
# Residuals (b) r = 11.2, v = 0.00162
#
# Convergence test: 0.944616, sigma_new(2.77e+03) < sigma_old(5e+04)
#
# #################### ITERATION 2 ####################
#
# Condition number (A): 89.031
# Condition number (ATWA_acc): 2.905195589892679e+17
# Lambda:  0.01
# Residuals after/before 2.53e+04 < 2.56e+04
# Covariance a: 0.034 m
# dx  [ 5.17038556e-05  1.53680567e-07  1.44584083e-08  7.90900795e-08
#   5.59810316e-08  4.78653520e-07 -2.33605006e-15]
# COE elements = [26560.405219684693, 0.0052350227770928594, 0.95373863930629, 5.586317314468845, 4.617536284328352, 0.0879434948426372, -0.13408946323670515]
# EQN elements = (26560.405219684693, -0.003725050182059452, -0.003678242055360125, 4.008611786460248, -0.33158816938760977, 0.3961870924343243, -0.13408946323670515)
# Residual (b) = [ 1.53442726e-01 -1.25732767e-01 -5.94065392e-02 -1.68431149e-06
#   7.47311415e-06  1.79897416e-07]
# Residuals (b) r = 0.207, v = 7.66e-06
#
# Convergence test: 0.99807, sigma_new(5.35) < sigma_old(2.77e+03)
#
# #################### ITERATION 3 ####################
#
# Condition number (A): 89.031
# Condition number (ATWA_acc): 3.5485946141672986e+17
# Lambda:  0.001
# Residuals after/before 2.53e+04 < 2.53e+04
# Covariance a: 0.034 m
# dx  [-6.62030883e-09 -1.97747203e-14 -5.30932857e-13  3.65659377e-12
#   1.66833164e-12 -1.40351631e-12 -1.27170954e-19]
# COE elements = [26560.405219678072, 0.005235022777479975, 0.9537386393029006, 5.586317314469578, 4.617536284397132, 0.08794349477678232, -0.13408946323670515]
# EQN elements = (26560.405219678072, -0.0037250501820792255, -0.0036782420558910587, 4.008611786463906, -0.3315881693859414, 0.3961870924329208, -0.13408946323670515)
# Residual (b) = [ 1.56258281e-01 -1.39070312e-01 -5.11207691e-02 -2.04973750e-06
#   6.03300635e-06  2.46323463e-06]
# Residuals (b) r = 0.215, v = 6.83e-06
#
# Convergence test: 0.00747152, sigma_new(5.31) < sigma_old(5.35)
#
# Stopped due to residual convergence
#
# #################### SOLUTION IN 3 ITERATIONS ####################
#
# Solution 26560.405219678072 0.0052350 54.6452 320.0724 264.5653 5.0388 -1.3409e-01
# Original 26558.66821181454 0.0049560 54.6305 320.0891 264.0673 5.5093 +1.0000e-06
# Residuals (b) r = 0.215, v = 6.83e-06
# Stopped in 3 iterations
# Residual at epoch     1.176e+01 km 1.762e-03 km/s
# Residual at new epoch 2.172e-01 km 0.000e+00 km/s
# Residual at the end   2.153e-01 km 6.831e-06 km/s

# %%
# Split the data into in-spampe and out-of-sample

# Optionally thin the observations
t_is = tt = t[::obs_stride]
eph_is = teph = ephemeris[::obs_stride]

if last_obs:
    t_os = t_is[last_obs:]
    t_is = t_is[:last_obs]
    eph_os = eph_is[last_obs:]
    eph_is = eph_is[:last_obs]

jd, jdf = solve_sat.model.jdsatepoch, solve_sat.model.jdsatepochF
print(sat_epoch_datetime(solve_sat.model))
# Out:
# 2006-10-19 02:44:46.999968+00:00

# %%
exporter.export_tle(solve_sat.model)
# Out:
# ('1 99999U 1800100  06292.11443287  .00000000  00000-0 -13409+0 0  9991',
#  '2 99999  54.6452 320.0724 0052350 264.5653   5.0388  2.00563044    16')

# %%
plt.semilogy(range(len(sigmas)), sigmas)

# %%
plt.semilogy(bs)

# %%
def solution_residuals(t, ephemeris, solve_sat):
    
    bs = []
    
    offset_idxs = range(len(t))
    
    for offset_idx in offset_idxs:

        # Obs - Nom
        jd, jdf = jday_datetime(t[offset_idx])
        res = np.array(ephemeris[offset_idx]) - np.array(solve_sat.model.sgp4(jd, jdf)[1:])
        
        b = np.concatenate((res[0], res[1]))

        #bs.append(np.linalg.norm(b.T @ W @ b))
        bs.append(np.linalg.norm(b.T @ b))
        
    return np.array(bs)

# %%
plt.plot(solution_residuals(t_is, eph_is, solve_sat) * 1000, c='g')
plt.plot(range(last_obs, len(tt)), solution_residuals(t_os, eph_os, solve_sat) * 1000, c='r')

plt.xlabel('Observations')
plt.ylabel('Residuals (m)')
plt.grid()

# %%
plt.semilogy(solution_residuals(t_is, eph_is, solve_sat) * 1000, c='g')
plt.semilogy(range(last_obs, len(tt)), solution_residuals(t_os, eph_os, solve_sat) * 1000, c='r')

# %% [markdown]
# ## Find the distance to TLEs with the same launch and proximate epoch

# %%
import datetime as dt

import json

from sgp4.conveniences import sat_epoch_datetime, jday_datetime

from spacetrack import SpaceTrackClient
import spacetrack.operators as op

st = SpaceTrackClient(os.environ['SPACETRACK_USER'], os.environ['SPACETRACK_PWD'])

# %%
launch_objects = json.loads(st.gp(mean_motion=op.inclusive_range(1.95, 2.05), orderby='TLE_LINE1', format='json'))

# %%
[lo for lo in launch_objects if 'NAVSTAR' in lo['OBJECT_NAME']]
# Out:
# [{'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'OPS 5111 (NAVSTAR 1)',
#   'OBJECT_ID': '1978-020A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T02:42:08.339328',
#   'MEAN_MOTION': '1.98072313',
#   'ECCENTRICITY': '0.00810510',
#   'INCLINATION': '63.4576',
#   'RA_OF_ASC_NODE': '90.9769',
#   'ARG_OF_PERICENTER': '212.2486',
#   'MEAN_ANOMALY': '147.2602',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '10684',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '31114',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000012',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26782.595',
#   'PERIOD': '727.007',
#   'APOAPSIS': '20621.536',
#   'PERIAPSIS': '20187.385',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'MEDIUM',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '1978-02-22',
#   'SITE': 'AFWTR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220806935',
#   'TLE_LINE0': '0 OPS 5111 (NAVSTAR 1)',
#   'TLE_LINE1': '1 10684U 78020A   22352.11259652 -.00000012  00000-0  00000-0 0  9995',
#   'TLE_LINE2': '2 10684  63.4576  90.9769 0081051 212.2486 147.2602  1.98072313311148'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'OPS 5112 (NAVSTAR 2)',
#   'OBJECT_ID': '1978-047A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T04:34:56.052192',
#   'MEAN_MOTION': '2.01626461',
#   'ECCENTRICITY': '0.05110230',
#   'INCLINATION': '63.5848',
#   'RA_OF_ASC_NODE': '313.8237',
#   'ARG_OF_PERICENTER': '45.6525',
#   'MEAN_ANOMALY': '45.2481',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '10893',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '32798',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000034',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26466.925',
#   'PERIOD': '714.192',
#   'APOAPSIS': '21441.311',
#   'PERIAPSIS': '18736.269',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'MEDIUM',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '1978-05-13',
#   'SITE': 'AFWTR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220808201',
#   'TLE_LINE0': '0 OPS 5112 (NAVSTAR 2)',
#   'TLE_LINE1': '1 10893U 78047A   22352.19092653 -.00000034  00000-0  00000-0 0  9994',
#   'TLE_LINE2': '2 10893  63.5848 313.8237 0511023  45.6525  45.2481  2.01626461327984'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-15T18:29:43',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'OPS 5117 (NAVSTAR 5)',
#   'OBJECT_ID': '1980-011A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-15T12:19:16.474368',
#   'MEAN_MOTION': '2.00556358',
#   'ECCENTRICITY': '0.04830510',
#   'INCLINATION': '63.8963',
#   'RA_OF_ASC_NODE': '88.0047',
#   'ARG_OF_PERICENTER': '202.9089',
#   'MEAN_ANOMALY': '157.2961',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '11690',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '32806',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000008',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.988',
#   'PERIOD': '718.003',
#   'APOAPSIS': '21465.884',
#   'PERIAPSIS': '18899.821',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'MEDIUM',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '1980-02-09',
#   'SITE': 'AFWTR',
#   'DECAY_DATE': None,
#   'FILE': '3702025',
#   'GP_ID': '220467840',
#   'TLE_LINE0': '0 OPS 5117 (NAVSTAR 5)',
#   'TLE_LINE1': '1 11690U 80011A   22349.51338512 -.00000008  00000-0  00000-0 0  9994',
#   'TLE_LINE2': '2 11690  63.8963  88.0047 0483051 202.9089 157.2961  2.00556358328066'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-16T20:15:47',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'OPS 5118 (NAVSTAR 6)',
#   'OBJECT_ID': '1980-032A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-16T07:33:10.890432',
#   'MEAN_MOTION': '2.03456197',
#   'ECCENTRICITY': '0.05340760',
#   'INCLINATION': '62.5684',
#   'RA_OF_ASC_NODE': '291.8652',
#   'ARG_OF_PERICENTER': '55.7976',
#   'MEAN_ANOMALY': '112.3805',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '11783',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '31573',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000029',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26308.004',
#   'PERIOD': '707.769',
#   'APOAPSIS': '21334.916',
#   'PERIAPSIS': '18524.821',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'MEDIUM',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '1980-04-26',
#   'SITE': 'AFWTR',
#   'DECAY_DATE': None,
#   'FILE': '3702730',
#   'GP_ID': '220564270',
#   'TLE_LINE0': '0 OPS 5118 (NAVSTAR 6)',
#   'TLE_LINE1': '1 11783U 80032A   22350.31470938 -.00000029  00000-0  00000-0 0  9992',
#   'TLE_LINE2': '2 11783  62.5684 291.8652 0534076  55.7976 112.3805  2.03456197315736'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 43 (USA 132)',
#   'OBJECT_ID': '1997-035A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T08:07:22.225152',
#   'MEAN_MOTION': '2.00563752',
#   'ECCENTRICITY': '0.00654400',
#   'INCLINATION': '55.5389',
#   'RA_OF_ASC_NODE': '148.4973',
#   'ARG_OF_PERICENTER': '53.3155',
#   'MEAN_ANOMALY': '307.2835',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '24876',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '18634',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000105',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.335',
#   'PERIOD': '717.976',
#   'APOAPSIS': '20356.011',
#   'PERIAPSIS': '20008.389',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '1997-07-23',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220811958',
#   'TLE_LINE0': '0 NAVSTAR 43 (USA 132)',
#   'TLE_LINE1': '1 24876U 97035A   22352.33845168  .00000105  00000-0  00000-0 0  9999',
#   'TLE_LINE2': '2 24876  55.5389 148.4973 0065440  53.3155 307.2835  2.00563752186341'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 46 (USA 145)',
#   'OBJECT_ID': '1999-055A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T04:34:42.714624',
#   'MEAN_MOTION': '2.00572428',
#   'ECCENTRICITY': '0.01361810',
#   'INCLINATION': '52.3533',
#   'RA_OF_ASC_NODE': '350.7635',
#   'ARG_OF_PERICENTER': '136.7710',
#   'MEAN_ANOMALY': '41.5163',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '25933',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '16996',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000062',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.569',
#   'PERIOD': '717.945',
#   'APOAPSIS': '20543.125',
#   'PERIAPSIS': '19819.743',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '1999-10-07',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220811008',
#   'TLE_LINE0': '0 NAVSTAR 46 (USA 145)',
#   'TLE_LINE1': '1 25933U 99055A   22352.19077216 -.00000062  00000-0  00000-0 0  9996',
#   'TLE_LINE2': '2 25933  52.3533 350.7635 0136181 136.7710  41.5163  2.00572428169960'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 47 (USA 150)',
#   'OBJECT_ID': '2000-025A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T07:41:47.433696',
#   'MEAN_MOTION': '2.00559487',
#   'ECCENTRICITY': '0.00470810',
#   'INCLINATION': '54.2110',
#   'RA_OF_ASC_NODE': '71.2840',
#   'ARG_OF_PERICENTER': '191.5275',
#   'MEAN_ANOMALY': '246.7850',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '26360',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '16566',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000048',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.711',
#   'PERIOD': '717.991',
#   'APOAPSIS': '20307.627',
#   'PERIAPSIS': '20057.526',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2000-05-11',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220811286',
#   'TLE_LINE0': '0 NAVSTAR 47 (USA 150)',
#   'TLE_LINE1': '1 26360U 00025A   22352.32068789 -.00000048  00000-0  00000-0 0  9994',
#   'TLE_LINE2': '2 26360  54.2110  71.2840 0047081 191.5275 246.7850  2.00559487165660'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 48 (USA 151)',
#   'OBJECT_ID': '2000-040A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T04:08:40.839360',
#   'MEAN_MOTION': '2.00566599',
#   'ECCENTRICITY': '0.01629330',
#   'INCLINATION': '55.3486',
#   'RA_OF_ASC_NODE': '265.9552',
#   'ARG_OF_PERICENTER': '289.3380',
#   'MEAN_ANOMALY': '238.7227',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '26407',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '16433',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000011',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.083',
#   'PERIOD': '717.966',
#   'APOAPSIS': '20614.700',
#   'PERIAPSIS': '19749.197',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2000-07-16',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220811289',
#   'TLE_LINE0': '0 NAVSTAR 48 (USA 151)',
#   'TLE_LINE1': '1 26407U 00040A   22352.17269490 -.00000011  00000-0  00000-0 0  9998',
#   'TLE_LINE2': '2 26407  55.3486 265.9552 0162933 289.3380 238.7227  2.00566599164333'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 49 (USA 154)',
#   'OBJECT_ID': '2000-071A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T06:51:09.951840',
#   'MEAN_MOTION': '2.00552723',
#   'ECCENTRICITY': '0.01385750',
#   'INCLINATION': '55.1262',
#   'RA_OF_ASC_NODE': '145.4138',
#   'ARG_OF_PERICENTER': '254.7108',
#   'MEAN_ANOMALY': '281.0183',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '26605',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '16190',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000100',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26561.308',
#   'PERIOD': '718.016',
#   'APOAPSIS': '20551.247',
#   'PERIAPSIS': '19815.100',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2000-11-10',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220811551',
#   'TLE_LINE0': '0 NAVSTAR 49 (USA 154)',
#   'TLE_LINE1': '1 26605U 00071A   22352.28553185  .00000100  00000-0  00000-0 0  9999',
#   'TLE_LINE2': '2 26605  55.1262 145.4138 0138575 254.7108 281.0183  2.00552723161900'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 51 (USA 166)',
#   'OBJECT_ID': '2003-005A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T23:29:46.819104',
#   'MEAN_MOTION': '2.00553775',
#   'ECCENTRICITY': '0.01301880',
#   'INCLINATION': '55.3937',
#   'RA_OF_ASC_NODE': '265.7702',
#   'ARG_OF_PERICENTER': '41.9762',
#   'MEAN_ANOMALY': '124.8748',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '27663',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '14569',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000012',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26561.216',
#   'PERIOD': '718.012',
#   'APOAPSIS': '20528.876',
#   'PERIAPSIS': '19837.285',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2003-01-29',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220812104',
#   'TLE_LINE0': '0 NAVSTAR 51 (USA 166)',
#   'TLE_LINE1': '1 27663U 03005A   22351.97901411 -.00000012  00000-0  00000-0 0  9991',
#   'TLE_LINE2': '2 27663  55.3937 265.7702 0130188  41.9762 124.8748  2.00553775145690'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 52 (USA 168)',
#   'OBJECT_ID': '2003-010A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T11:18:52.807392',
#   'MEAN_MOTION': '2.00564089',
#   'ECCENTRICITY': '0.02484740',
#   'INCLINATION': '55.0781',
#   'RA_OF_ASC_NODE': '15.8639',
#   'ARG_OF_PERICENTER': '310.8338',
#   'MEAN_ANOMALY': '68.6634',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '27704',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '14450',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000060',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.305',
#   'PERIOD': '717.975',
#   'APOAPSIS': '20842.125',
#   'PERIAPSIS': '19522.215',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2003-03-31',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220812607',
#   'TLE_LINE0': '0 NAVSTAR 52 (USA 168)',
#   'TLE_LINE1': '1 27704U 03010A   22352.47144453 -.00000060  00000-0  00000-0 0  9997',
#   'TLE_LINE2': '2 27704  55.0781  15.8639 0248474 310.8338  68.6634  2.00564089144506'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 53 (USA 175)',
#   'OBJECT_ID': '2003-058A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T12:44:08.393280',
#   'MEAN_MOTION': '2.00564213',
#   'ECCENTRICITY': '0.00682450',
#   'INCLINATION': '54.0298',
#   'RA_OF_ASC_NODE': '73.8866',
#   'ARG_OF_PERICENTER': '320.3063',
#   'MEAN_ANOMALY': '39.2217',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '28129',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '13916',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000044',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.294',
#   'PERIOD': '717.975',
#   'APOAPSIS': '20363.420',
#   'PERIAPSIS': '20000.898',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2003-12-21',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220812383',
#   'TLE_LINE0': '0 NAVSTAR 53 (USA 175)',
#   'TLE_LINE1': '1 28129U 03058A   22351.53065270 -.00000044  00000-0  00000-0 0  9998',
#   'TLE_LINE2': '2 28129  54.0298  73.8866 0068245 320.3063  39.2217  2.00564213139169'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 54 (USA 177)',
#   'OBJECT_ID': '2004-009A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T12:37:42.680352',
#   'MEAN_MOTION': '2.00556018',
#   'ECCENTRICITY': '0.00882430',
#   'INCLINATION': '55.8861',
#   'RA_OF_ASC_NODE': '326.7700',
#   'ARG_OF_PERICENTER': '128.4294',
#   'MEAN_ANOMALY': '228.0094',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '28190',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '13733',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000052',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26561.018',
#   'PERIOD': '718.004',
#   'APOAPSIS': '20417.265',
#   'PERIAPSIS': '19948.500',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2004-03-20',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220812635',
#   'TLE_LINE0': '0 NAVSTAR 54 (USA 177)',
#   'TLE_LINE1': '1 28190U 04009A   22352.52618843 -.00000052  00000-0  00000-0 0  9992',
#   'TLE_LINE2': '2 28190  55.8861 326.7700 0088243 128.4294 228.0094  2.00556018137334'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T02:46:40',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 55 (USA 178)',
#   'OBJECT_ID': '2004-023A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T19:27:53.533728',
#   'MEAN_MOTION': '2.00571332',
#   'ECCENTRICITY': '0.01431540',
#   'INCLINATION': '54.2199',
#   'RA_OF_ASC_NODE': '138.4563',
#   'ARG_OF_PERICENTER': '264.4546',
#   'MEAN_ANOMALY': '116.4364',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '28361',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '13542',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000087',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.666',
#   'PERIOD': '717.949',
#   'APOAPSIS': '20561.743',
#   'PERIAPSIS': '19801.318',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2004-06-23',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3707070',
#   'GP_ID': '220741384',
#   'TLE_LINE0': '0 NAVSTAR 55 (USA 178)',
#   'TLE_LINE1': '1 28361U 04023A   22351.81103627  .00000087  00000-0  00000-0 0  9995',
#   'TLE_LINE2': '2 28361  54.2199 138.4563 0143154 264.4546 116.4364  2.00571332135424'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 56 (USA 180)',
#   'OBJECT_ID': '2004-045A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T11:20:37.657248',
#   'MEAN_MOTION': '2.00561635',
#   'ECCENTRICITY': '0.02029170',
#   'INCLINATION': '55.4032',
#   'RA_OF_ASC_NODE': '16.0751',
#   'ARG_OF_PERICENTER': '282.4789',
#   'MEAN_ANOMALY': '248.0352',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '28474',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '13282',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000059',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.522',
#   'PERIOD': '717.984',
#   'APOAPSIS': '20721.345',
#   'PERIAPSIS': '19643.429',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2004-11-06',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220811652',
#   'TLE_LINE0': '0 NAVSTAR 56 (USA 180)',
#   'TLE_LINE1': '1 28474U 04045A   22352.47265807 -.00000059  00000-0  00000-0 0  9996',
#   'TLE_LINE2': '2 28474  55.4032  16.0751 0202917 282.4789 248.0352  2.00561635132825'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 57 (USA 183)',
#   'OBJECT_ID': '2005-038A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T04:16:18.263424',
#   'MEAN_MOTION': '2.00563340',
#   'ECCENTRICITY': '0.01406670',
#   'INCLINATION': '55.9454',
#   'RA_OF_ASC_NODE': '324.2250',
#   'ARG_OF_PERICENTER': '277.1360',
#   'MEAN_ANOMALY': '217.7637',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '28874',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '12622',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000051',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.371',
#   'PERIOD': '717.978',
#   'APOAPSIS': '20555.853',
#   'PERIAPSIS': '19808.619',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2005-09-26',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220814181',
#   'TLE_LINE0': '0 NAVSTAR 57 (USA 183)',
#   'TLE_LINE1': '1 28874U 05038A   22352.17798916 -.00000051  00000-0  00000-0 0  9994',
#   'TLE_LINE2': '2 28874  55.9454 324.2250 0140667 277.1360 217.7637  2.00563340126220'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 58 (USA 190)',
#   'OBJECT_ID': '2006-042A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T09:04:41.183616',
#   'MEAN_MOTION': '2.00568488',
#   'ECCENTRICITY': '0.01066180',
#   'INCLINATION': '54.6977',
#   'RA_OF_ASC_NODE': '201.9669',
#   'ARG_OF_PERICENTER': '26.4483',
#   'MEAN_ANOMALY': '168.0977',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '29486',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '11878',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000113',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.917',
#   'PERIOD': '717.959',
#   'APOAPSIS': '20464.958',
#   'PERIAPSIS': '19898.605',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2006-09-25',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220813969',
#   'TLE_LINE0': '0 NAVSTAR 58 (USA 190)',
#   'TLE_LINE1': '1 29486U 06042A   22352.37825444  .00000113  00000-0  00000-0 0  9997',
#   'TLE_LINE2': '2 29486  54.6977 201.9669 0106618  26.4483 168.0977  2.00568488118785'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 59 (USA 192)',
#   'OBJECT_ID': '2006-052A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T01:25:10.314624',
#   'MEAN_MOTION': '2.00561119',
#   'ECCENTRICITY': '0.00851920',
#   'INCLINATION': '55.4061',
#   'RA_OF_ASC_NODE': '264.7130',
#   'ARG_OF_PERICENTER': '75.2718',
#   'MEAN_ANOMALY': '285.7116',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '29601',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '11779',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000010',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.567',
#   'PERIOD': '717.986',
#   'APOAPSIS': '20408.707',
#   'PERIAPSIS': '19956.157',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2006-11-17',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220812972',
#   'TLE_LINE0': '0 NAVSTAR 59 (USA 192)',
#   'TLE_LINE1': '1 29601U 06052A   22352.05914716 -.00000010  00000-0  00000-0 0  9990',
#   'TLE_LINE2': '2 29601  55.4061 264.7130 0085192  75.2718 285.7116  2.00561119117799'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 60 (USA 196)',
#   'OBJECT_ID': '2007-047A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T08:40:23.111040',
#   'MEAN_MOTION': '2.00565408',
#   'ECCENTRICITY': '0.01454450',
#   'INCLINATION': '53.3703',
#   'RA_OF_ASC_NODE': '132.9196',
#   'ARG_OF_PERICENTER': '66.5927',
#   'MEAN_ANOMALY': '294.9127',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '32260',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '11120',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000071',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.189',
#   'PERIOD': '717.970',
#   'APOAPSIS': '20568.358',
#   'PERIAPSIS': '19795.749',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2007-10-17',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220814722',
#   'TLE_LINE0': '0 NAVSTAR 60 (USA 196)',
#   'TLE_LINE1': '1 32260U 07047A   22352.36137860  .00000071  00000-0  00000-0 0  9997',
#   'TLE_LINE2': '2 32260  53.3703 132.9196 0145445  66.5927 294.9127  2.00565408111204'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 61 (USA 199)',
#   'OBJECT_ID': '2007-062A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T10:27:26.682336',
#   'MEAN_MOTION': '2.00571746',
#   'ECCENTRICITY': '0.00196320',
#   'INCLINATION': '56.0698',
#   'RA_OF_ASC_NODE': '325.0005',
#   'ARG_OF_PERICENTER': '146.0363',
#   'MEAN_ANOMALY': '35.3897',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '32384',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '10990',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000051',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.629',
#   'PERIOD': '717.948',
#   'APOAPSIS': '20233.636',
#   'PERIAPSIS': '20129.352',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2007-12-20',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220816784',
#   'TLE_LINE0': '0 NAVSTAR 61 (USA 199)',
#   'TLE_LINE1': '1 32384U 07062A   22352.43572549 -.00000051  00000-0  00000-0 0  9995',
#   'TLE_LINE2': '2 32384  56.0698 325.0005 0019632 146.0363  35.3897  2.00571746109901'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 62 (USA 201)',
#   'OBJECT_ID': '2008-012A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T18:41:26.601504',
#   'MEAN_MOTION': '2.00570695',
#   'ECCENTRICITY': '0.01668690',
#   'INCLINATION': '54.4609',
#   'RA_OF_ASC_NODE': '200.8839',
#   'ARG_OF_PERICENTER': '232.4577',
#   'MEAN_ANOMALY': '126.0900',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '32711',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '10813',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000108',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.722',
#   'PERIOD': '717.951',
#   'APOAPSIS': '20624.786',
#   'PERIAPSIS': '19738.387',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2008-03-15',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220815497',
#   'TLE_LINE0': '0 NAVSTAR 62 (USA 201)',
#   'TLE_LINE1': '1 32711U 08012A   22351.77878011  .00000108  00000-0  00000-0 0  9996',
#   'TLE_LINE2': '2 32711  54.4609 200.8839 0166869 232.4577 126.0900  2.00570695108135'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-16T20:15:47',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 63 (USA 203)',
#   'OBJECT_ID': '2009-014A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-15T22:45:26.125056',
#   'MEAN_MOTION': '2.00570955',
#   'ECCENTRICITY': '0.01243050',
#   'INCLINATION': '54.9473',
#   'RA_OF_ASC_NODE': '262.0288',
#   'ARG_OF_PERICENTER': '55.7912',
#   'MEAN_ANOMALY': '125.9459',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '34661',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '10062',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000016',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.699',
#   'PERIOD': '717.950',
#   'APOAPSIS': '20511.714',
#   'PERIAPSIS': '19851.414',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2009-03-24',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3702730',
#   'GP_ID': '220571912',
#   'TLE_LINE0': '0 NAVSTAR 63 (USA 203)',
#   'TLE_LINE1': '1 34661U 09014A   22349.94821904 -.00000016  00000-0  00000-0 0  9999',
#   'TLE_LINE2': '2 34661  54.9473 262.0288 0124305  55.7912 125.9459  2.00570955100623'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 64 (USA 206)',
#   'OBJECT_ID': '2009-043A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T07:29:52.859040',
#   'MEAN_MOTION': '2.00574475',
#   'ECCENTRICITY': '0.00562220',
#   'INCLINATION': '55.2170',
#   'RA_OF_ASC_NODE': '78.1364',
#   'ARG_OF_PERICENTER': '64.4319',
#   'MEAN_ANOMALY': '333.6639',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '35752',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '9775',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000039',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.388',
#   'PERIOD': '717.938',
#   'APOAPSIS': '20330.575',
#   'PERIAPSIS': '20031.931',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2009-08-17',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220818988',
#   'TLE_LINE0': '0 NAVSTAR 64 (USA 206)',
#   'TLE_LINE1': '1 35752U 09043A   22352.31241735 -.00000039  00000-0  00000-0 0  9991',
#   'TLE_LINE2': '2 35752  55.2170  78.1364 0056222  64.4319 333.6639  2.00574475 97752'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 65 (USA 213)',
#   'OBJECT_ID': '2010-022A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T06:11:35.937312',
#   'MEAN_MOTION': '2.00574927',
#   'ECCENTRICITY': '0.01077900',
#   'INCLINATION': '54.6950',
#   'RA_OF_ASC_NODE': '260.0967',
#   'ARG_OF_PERICENTER': '57.2024',
#   'MEAN_ANOMALY': '63.6209',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '36585',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '9198',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000001',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.348',
#   'PERIOD': '717.936',
#   'APOAPSIS': '20467.496',
#   'PERIAPSIS': '19894.930',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2010-05-28',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220817547',
#   'TLE_LINE0': '0 NAVSTAR 65 (USA 213)',
#   'TLE_LINE1': '1 36585U 10022A   22352.25805483 -.00000001  00000-0  00000-0 0  9993',
#   'TLE_LINE2': '2 36585  54.6950 260.0967 0107790  57.2024  63.6209  2.00574927 91981'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 66 (USA 232)',
#   'OBJECT_ID': '2011-036A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T11:31:08.010048',
#   'MEAN_MOTION': '2.00566411',
#   'ECCENTRICITY': '0.01191200',
#   'INCLINATION': '56.6766',
#   'RA_OF_ASC_NODE': '21.5487',
#   'ARG_OF_PERICENTER': '53.0638',
#   'MEAN_ANOMALY': '308.6565',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '37753',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '8367',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000058',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.100',
#   'PERIOD': '717.967',
#   'APOAPSIS': '20498.349',
#   'PERIAPSIS': '19865.581',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2011-07-16',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220818884',
#   'TLE_LINE0': '0 NAVSTAR 66 (USA 232)',
#   'TLE_LINE1': '1 37753U 11036A   22352.47995382 -.00000058  00000-0  00000-0 0  9991',
#   'TLE_LINE2': '2 37753  56.6766  21.5487 0119120  53.0638 308.6565  2.00566411 83671'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 67 (USA 239)',
#   'OBJECT_ID': '2012-053A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T23:06:51.668064',
#   'MEAN_MOTION': '2.00563945',
#   'ECCENTRICITY': '0.01340040',
#   'INCLINATION': '53.5185',
#   'RA_OF_ASC_NODE': '195.8393',
#   'ARG_OF_PERICENTER': '49.2747',
#   'MEAN_ANOMALY': '311.9547',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '38833',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '7382',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000114',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.318',
#   'PERIOD': '717.976',
#   'APOAPSIS': '20538.102',
#   'PERIAPSIS': '19826.264',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2012-10-04',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220820487',
#   'TLE_LINE0': '0 NAVSTAR 67 (USA 239)',
#   'TLE_LINE1': '1 38833U 12053A   22351.96309801  .00000114  00000-0  00000-0 0  9991',
#   'TLE_LINE2': '2 38833  53.5185 195.8393 0134004  49.2747 311.9547  2.00563945 73821'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T02:46:40',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 68 (USA 242)',
#   'OBJECT_ID': '2013-023A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T07:44:52.512864',
#   'MEAN_MOTION': '2.00565158',
#   'ECCENTRICITY': '0.01081750',
#   'INCLINATION': '55.5673',
#   'RA_OF_ASC_NODE': '320.5600',
#   'ARG_OF_PERICENTER': '38.2305',
#   'MEAN_ANOMALY': '322.5352',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '39166',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '7025',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000050',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.211',
#   'PERIOD': '717.971',
#   'APOAPSIS': '20469.391',
#   'PERIAPSIS': '19894.761',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2013-05-15',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3707070',
#   'GP_ID': '220749493',
#   'TLE_LINE0': '0 NAVSTAR 68 (USA 242)',
#   'TLE_LINE1': '1 39166U 13023A   22351.32283001 -.00000050  00000-0  00000-0 0  9992',
#   'TLE_LINE2': '2 39166  55.5673 320.5600 0108175  38.2305 322.5352  2.00565158 70255'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 69 (USA 248)',
#   'OBJECT_ID': '2014-008A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T19:47:20.749344',
#   'MEAN_MOTION': '2.00563829',
#   'ECCENTRICITY': '0.00607610',
#   'INCLINATION': '53.6090',
#   'RA_OF_ASC_NODE': '201.3715',
#   'ARG_OF_PERICENTER': '209.0318',
#   'MEAN_ANOMALY': '150.7053',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '39533',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '6406',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000106',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.328',
#   'PERIOD': '717.976',
#   'APOAPSIS': '20343.576',
#   'PERIAPSIS': '20020.810',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2014-02-21',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220819531',
#   'TLE_LINE0': '0 NAVSTAR 69 (USA 248)',
#   'TLE_LINE1': '1 39533U 14008A   22351.82454571  .00000106  00000-0  00000-0 0  9992',
#   'TLE_LINE2': '2 39533  53.6090 201.3715 0060761 209.0318 150.7053  2.00563829 64062'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 70 (USA 251)',
#   'OBJECT_ID': '2014-026A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T02:27:33.147072',
#   'MEAN_MOTION': '2.00575612',
#   'ECCENTRICITY': '0.00295530',
#   'INCLINATION': '56.6347',
#   'RA_OF_ASC_NODE': '21.0883',
#   'ARG_OF_PERICENTER': '305.3920',
#   'MEAN_ANOMALY': '54.3910',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '39741',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '6292',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000059',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.288',
#   'PERIOD': '717.934',
#   'APOAPSIS': '20259.643',
#   'PERIAPSIS': '20102.662',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2014-05-17',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220820301',
#   'TLE_LINE0': '0 NAVSTAR 70 (USA 251)',
#   'TLE_LINE1': '1 39741U 14026A   22352.10246698 -.00000059  00000-0  00000-0 0  9992',
#   'TLE_LINE2': '2 39741  56.6347  21.0883 0029553 305.3920  54.3910  2.00575612 62924'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 71 (USA 256)',
#   'OBJECT_ID': '2014-045A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T16:38:48.112224',
#   'MEAN_MOTION': '2.00559555',
#   'ECCENTRICITY': '0.00242620',
#   'INCLINATION': '54.7370',
#   'RA_OF_ASC_NODE': '139.4865',
#   'ARG_OF_PERICENTER': '113.3511',
#   'MEAN_ANOMALY': '246.8953',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '40105',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '6045',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000090',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.705',
#   'PERIOD': '717.991',
#   'APOAPSIS': '20247.012',
#   'PERIAPSIS': '20118.129',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2014-08-02',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220820087',
#   'TLE_LINE0': '0 NAVSTAR 71 (USA 256)',
#   'TLE_LINE1': '1 40105U 14045A   22351.69361241  .00000090  00000-0  00000-0 0  9998',
#   'TLE_LINE2': '2 40105  54.7370 139.4865 0024262 113.3511 246.8953  2.00559555 60453'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 72 (USA 258)',
#   'OBJECT_ID': '2014-068A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T13:30:48.523104',
#   'MEAN_MOTION': '2.00554052',
#   'ECCENTRICITY': '0.00422010',
#   'INCLINATION': '55.9598',
#   'RA_OF_ASC_NODE': '80.7128',
#   'ARG_OF_PERICENTER': '58.1784',
#   'MEAN_ANOMALY': '302.2482',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '40294',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '5958',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000033',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26561.191',
#   'PERIOD': '718.011',
#   'APOAPSIS': '20295.147',
#   'PERIAPSIS': '20070.965',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2014-10-29',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220820856',
#   'TLE_LINE0': '0 NAVSTAR 72 (USA 258)',
#   'TLE_LINE1': '1 40294U 14068A   22351.56306161 -.00000033  00000-0  00000-0 0  9996',
#   'TLE_LINE2': '2 40294  55.9598  80.7128 0042201  58.1784 302.2482  2.00554052 59581'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 73 (USA 260)',
#   'OBJECT_ID': '2015-013A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T04:48:25.188192',
#   'MEAN_MOTION': '2.00570744',
#   'ECCENTRICITY': '0.00754960',
#   'INCLINATION': '53.5946',
#   'RA_OF_ASC_NODE': '257.0807',
#   'ARG_OF_PERICENTER': '22.2140',
#   'MEAN_ANOMALY': '338.1642',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '40534',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '5621',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000003',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.717',
#   'PERIOD': '717.951',
#   'APOAPSIS': '20382.098',
#   'PERIAPSIS': '19981.067',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2015-03-25',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220819875',
#   'TLE_LINE0': '0 NAVSTAR 73 (USA 260)',
#   'TLE_LINE1': '1 40534U 15013A   22352.20029153  .00000003  00000-0  00000-0 0  9995',
#   'TLE_LINE2': '2 40534  53.5946 257.0807 0075496  22.2140 338.1642  2.00570744 56211'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T02:46:40',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 74 (USA 262)',
#   'OBJECT_ID': '2015-033A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T20:38:30.753888',
#   'MEAN_MOTION': '2.00568588',
#   'ECCENTRICITY': '0.00795470',
#   'INCLINATION': '55.0609',
#   'RA_OF_ASC_NODE': '319.2792',
#   'ARG_OF_PERICENTER': '8.5509',
#   'MEAN_ANOMALY': '351.5853',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '40730',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '5437',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000052',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.908',
#   'PERIOD': '717.959',
#   'APOAPSIS': '20393.049',
#   'PERIAPSIS': '19970.497',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2015-07-15',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3707070',
#   'GP_ID': '220749129',
#   'TLE_LINE0': '0 NAVSTAR 74 (USA 262)',
#   'TLE_LINE1': '1 40730U 15033A   22351.86007817 -.00000052  00000-0  00000-0 0  9994',
#   'TLE_LINE2': '2 40730  55.0609 319.2792 0079547   8.5509 351.5853  2.00568588 54374'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 75 (USA 265)',
#   'OBJECT_ID': '2015-062A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T09:52:17.316192',
#   'MEAN_MOTION': '2.00561839',
#   'ECCENTRICITY': '0.00845740',
#   'INCLINATION': '55.9472',
#   'RA_OF_ASC_NODE': '80.5255',
#   'ARG_OF_PERICENTER': '219.2268',
#   'MEAN_ANOMALY': '140.1741',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '41019',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '5222',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000035',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.504',
#   'PERIOD': '717.983',
#   'APOAPSIS': '20407.001',
#   'PERIAPSIS': '19957.736',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2015-10-31',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220821169',
#   'TLE_LINE0': '0 NAVSTAR 75 (USA 265)',
#   'TLE_LINE1': '1 41019U 15062A   22352.41131153 -.00000035  00000-0  00000-0 0  9991',
#   'TLE_LINE2': '2 41019  55.9472  80.5255 0084574 219.2268 140.1741  2.00561839 52225'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 76 (USA 266)',
#   'OBJECT_ID': '2016-007A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T11:57:16.812864',
#   'MEAN_MOTION': '2.00562057',
#   'ECCENTRICITY': '0.00651400',
#   'INCLINATION': '54.9495',
#   'RA_OF_ASC_NODE': '140.1700',
#   'ARG_OF_PERICENTER': '230.1197',
#   'MEAN_ANOMALY': '129.2963',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '41328',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '5023',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000088',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.484',
#   'PERIOD': '717.982',
#   'APOAPSIS': '20355.364',
#   'PERIAPSIS': '20009.334',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2016-02-05',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220819452',
#   'TLE_LINE0': '0 NAVSTAR 76 (USA 266)',
#   'TLE_LINE1': '1 41328U 16007A   22352.49811126  .00000088  00000-0  00000-0 0  9994',
#   'TLE_LINE2': '2 41328  54.9495 140.1700 0065140 230.1197 129.2963  2.00562057 50237'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 77 (USA 289)',
#   'OBJECT_ID': '2018-109A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T03:29:42.815616',
#   'MEAN_MOTION': '2.00557069',
#   'ECCENTRICITY': '0.00224090',
#   'INCLINATION': '55.1276',
#   'RA_OF_ASC_NODE': '142.6430',
#   'ARG_OF_PERICENTER': '187.8287',
#   'MEAN_ANOMALY': '167.9260',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '43873',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '2945',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '0.00000095',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.925',
#   'PERIOD': '718.000',
#   'APOAPSIS': '20242.310',
#   'PERIAPSIS': '20123.269',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2018-12-23',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220822696',
#   'TLE_LINE0': '0 NAVSTAR 77 (USA 289)',
#   'TLE_LINE1': '1 43873U 18109A   22352.14563444  .00000095  00000-0  00000-0 0  9993',
#   'TLE_LINE2': '2 43873  55.1276 142.6430 0022409 187.8287 167.9260  2.00557069 29456'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 78 (USA 293)',
#   'OBJECT_ID': '2019-056A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T14:12:09.824832',
#   'MEAN_MOTION': '2.00559977',
#   'ECCENTRICITY': '0.00298310',
#   'INCLINATION': '55.7519',
#   'RA_OF_ASC_NODE': '21.7355',
#   'ARG_OF_PERICENTER': '186.0103',
#   'MEAN_ANOMALY': '32.4687',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '44506',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '2446',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000060',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.668',
#   'PERIOD': '717.990',
#   'APOAPSIS': '20261.766',
#   'PERIAPSIS': '20103.300',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2019-08-22',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220823740',
#   'TLE_LINE0': '0 NAVSTAR 78 (USA 293)',
#   'TLE_LINE1': '1 44506U 19056A   22352.59178038 -.00000060  00000-0  00000-0 0  9992',
#   'TLE_LINE2': '2 44506  55.7519  21.7355 0029831 186.0103  32.4687  2.00559977 24468'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-17T18:13:04',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 79 (USA 304)',
#   'OBJECT_ID': '2020-041A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-17T08:49:20.828352',
#   'MEAN_MOTION': '2.00567616',
#   'ECCENTRICITY': '0.00293150',
#   'INCLINATION': '55.6659',
#   'RA_OF_ASC_NODE': '79.0549',
#   'ARG_OF_PERICENTER': '183.1129',
#   'MEAN_ANOMALY': '171.8085',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '45854',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '1840',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000035',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26559.994',
#   'PERIOD': '717.962',
#   'APOAPSIS': '20259.719',
#   'PERIAPSIS': '20103.998',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2020-06-30',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3705911',
#   'GP_ID': '220702456',
#   'TLE_LINE0': '0 NAVSTAR 79 (USA 304)',
#   'TLE_LINE1': '1 45854U 20041A   22351.36760218 -.00000035  00000-0  00000-0 0  9998',
#   'TLE_LINE2': '2 45854  55.6659  79.0549 0029315 183.1129 171.8085  2.00567616 18409'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 80 (USA 309)',
#   'OBJECT_ID': '2020-078A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T02:56:32.415360',
#   'MEAN_MOTION': '2.00564995',
#   'ECCENTRICITY': '0.00248910',
#   'INCLINATION': '54.4531',
#   'RA_OF_ASC_NODE': '262.6405',
#   'ARG_OF_PERICENTER': '190.0218',
#   'MEAN_ANOMALY': '326.4475',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '46826',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '1589',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000007',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.225',
#   'PERIOD': '717.972',
#   'APOAPSIS': '20248.201',
#   'PERIAPSIS': '20115.979',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2020-11-05',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220824719',
#   'TLE_LINE0': '0 NAVSTAR 80 (USA 309)',
#   'TLE_LINE1': '1 46826U 20078A   22352.12259740 -.00000007  00000-0  00000-0 0  9995',
#   'TLE_LINE2': '2 46826  54.4531 262.6405 0024891 190.0218 326.4475  2.00564995 15894'},
#  {'CCSDS_OMM_VERS': '2.0',
#   'COMMENT': 'GENERATED VIA SPACE-TRACK.ORG API',
#   'CREATION_DATE': '2022-12-18T17:49:27',
#   'ORIGINATOR': '18 SPCS',
#   'OBJECT_NAME': 'NAVSTAR 81 (USA 319)',
#   'OBJECT_ID': '2021-054A',
#   'CENTER_NAME': 'EARTH',
#   'REF_FRAME': 'TEME',
#   'TIME_SYSTEM': 'UTC',
#   'MEAN_ELEMENT_THEORY': 'SGP4',
#   'EPOCH': '2022-12-18T04:10:36.038208',
#   'MEAN_MOTION': '2.00563024',
#   'ECCENTRICITY': '0.00091540',
#   'INCLINATION': '55.2621',
#   'RA_OF_ASC_NODE': '23.6621',
#   'ARG_OF_PERICENTER': '214.8076',
#   'MEAN_ANOMALY': '163.4264',
#   'EPHEMERIS_TYPE': '0',
#   'CLASSIFICATION_TYPE': 'U',
#   'NORAD_CAT_ID': '48859',
#   'ELEMENT_SET_NO': '999',
#   'REV_AT_EPOCH': '1114',
#   'BSTAR': '0.00000000000000',
#   'MEAN_MOTION_DOT': '-0.00000062',
#   'MEAN_MOTION_DDOT': '0.0000000000000',
#   'SEMIMAJOR_AXIS': '26560.399',
#   'PERIOD': '717.979',
#   'APOAPSIS': '20206.577',
#   'PERIAPSIS': '20157.951',
#   'OBJECT_TYPE': 'PAYLOAD',
#   'RCS_SIZE': 'LARGE',
#   'COUNTRY_CODE': 'US',
#   'LAUNCH_DATE': '2021-06-17',
#   'SITE': 'AFETR',
#   'DECAY_DATE': None,
#   'FILE': '3708942',
#   'GP_ID': '220826194',
#   'TLE_LINE0': '0 NAVSTAR 81 (USA 319)',
#   'TLE_LINE1': '1 48859U 21054A   22352.17402822 -.00000062  00000-0  00000-0 0  9995',
#   'TLE_LINE2': '2 48859  55.2621  23.6621 0009154 214.8076 163.4264  2.00563024 11149'}]

# %%
tles = []

sat_ids = [sat['NORAD_CAT_ID'] for sat in launch_objects]

# %%
sat_gps = json.loads(st.gp_history(norad_cat_id=','.join(sat_ids),  epoch=op.inclusive_range((sat_epoch_datetime(solve_sat.model) - dt.timedelta(days=1)).date(), (sat_epoch_datetime(solve_sat.model) + dt.timedelta(days=+2)).date()), orderby='TLE_LINE1', format='json'))

# %%
def solution_residuals(t, solve_sat, comp_sat):
    
    bs = []
    
    offset_idxs = range(len(t))
    
    for offset_idx in offset_idxs:

        # Obs - Nom
        jd, jdf = jday_datetime(t[offset_idx])
        b = np.ravel(np.array(np.array(solve_sat.sgp4(jd, jdf)[1:] - np.array(comp_sat.sgp4(jd, jdf)[1:]))))[:3]

        bs.append(b.T @ b)
        
    return np.array(bs)

# %%
candidates = []

for sat in sat_gps:
    candidate_sat = EarthSatellite(sat['TLE_LINE1'], sat['TLE_LINE2'], sat['TLE_LINE0'], ts)

    res = solution_residuals(t_is, solve_sat.model, candidate_sat.model)
    res_epoch = np.sqrt(res[-1])
    res = np.sqrt(np.mean(res))

    candidates.append((sat["NORAD_CAT_ID"], sat["OBJECT_ID"], sat["EPOCH"], sat["TLE_LINE0"], sat["TLE_LINE1"], sat["TLE_LINE2"], res, res_epoch))

# %%
df_candidates = pd.DataFrame(candidates, columns=['norad_cat_id', 'object_id', 'epoch', 'tle_line0', 'tle_line1', 'tle_line2', 'residual', 'residual_epoch'])

# %%
df_candidates.sort_values('residual').head(20)
# Out:
#     norad_cat_id  object_id                       epoch  \
# 568        28129  2003-058A  2006-10-20T05:39:53.175168
# 567        28129  2003-058A  2006-10-19T05:43:58.315295
# 565        28129  2003-058A  2006-10-18T05:48:03.299040
# 566        28129  2003-058A  2006-10-18T05:48:03.325823
# 97         11690  1980-011A  2006-10-20T04:50:54.165120
# 95         11690  1980-011A  2006-10-18T04:59:07.223135
# 96         11690  1980-011A  2006-10-19T04:55:00.855263
# 64         10684  1978-020A  2006-10-18T05:30:29.613023
# 66         10684  1978-020A  2006-10-20T05:58:32.334239
# 67         10684  1978-020A  2006-10-20T05:58:32.596032
# 63         10684  1978-020A  2006-10-18T05:30:29.595744
# 65         10684  1978-020A  2006-10-19T05:44:31.917120
# 501        26605  2000-071A  2006-10-18T07:49:12.945792
# 502        26605  2000-071A  2006-10-19T07:45:09.124991
# 504        26605  2000-071A  2006-10-20T19:39:03.671136
# 503        26605  2000-071A  2006-10-19T19:43:07.401216
# 524        27704  2003-010A  2006-10-19T02:44:05.757791
# 526        27704  2003-010A  2006-10-20T02:40:00.590015
# 525        27704  2003-010A  2006-10-20T02:40:00.503615
# 523        27704  2003-010A  2006-10-18T02:48:11.539872
#
#                   tle_line0  \
# 568  0 NAVSTAR 53 (USA 175)
# 567  0 NAVSTAR 53 (USA 175)
# 565  0 NAVSTAR 53 (USA 175)
# 566  0 NAVSTAR 53 (USA 175)
# 97   0 OPS 5117 (NAVSTAR 5)
# 95   0 OPS 5117 (NAVSTAR 5)
# 96   0 OPS 5117 (NAVSTAR 5)
# 64   0 OPS 5111 (NAVSTAR 1)
# 66   0 OPS 5111 (NAVSTAR 1)
# 67   0 OPS 5111 (NAVSTAR 1)
# 63   0 OPS 5111 (NAVSTAR 1)
# 65   0 OPS 5111 (NAVSTAR 1)
# 501  0 NAVSTAR 49 (USA 154)
# 502  0 NAVSTAR 49 (USA 154)
# 504  0 NAVSTAR 49 (USA 154)
# 503  0 NAVSTAR 49 (USA 154)
# 524  0 NAVSTAR 52 (USA 168)
# 526  0 NAVSTAR 52 (USA 168)
# 525  0 NAVSTAR 52 (USA 168)
# 523  0 NAVSTAR 52 (USA 168)
#
#                                              tle_line1  \
# 568  1 28129U 03058A   06293.23603212 -.00000058  0...
# 567  1 28129U 03058A   06292.23886939 -.00000059 +0...
# 565  1 28129U 03058A   06291.24170485 -.00000059  0...
# 566  1 28129U 03058A   06291.24170516 -.00000059  0...
# 97   1 11690U 80011A   06293.20201580 -.00000012 +0...
# 95   1 11690U 80011A   06291.20772249 -.00000006  0...
# 96   1 11690U 80011A   06292.20487101 -.00000011 +0...
# 64   1 10684U 78020A   06291.22950941 -.00000008 +0...
# 66   1 10684U 78020A   06293.24898535 -.00000013 +0...
# 67   1 10684U 78020A   06293.24898838 -.00000013  0...
# 63   1 10684U 78020A   06291.22950921 -.00000008  0...
# 65   1 10684U 78020A   06292.23925830 -.00000012 +0...
# 501  1 26605U 00071A   06291.32584428 -.00000108 +0...
# 502  1 26605U 00071A   06292.32302228 -.00000104  0...
# 504  1 26605U 00071A   06293.81879249 -.00000096  0...
# 503  1 26605U 00071A   06292.82161344 -.00000102  0...
# 524  1 27704U 03010A   06292.11395553 -.00000038  0...
# 526  1 27704U 03010A   06293.11111794 -.00000035  0...
# 525  1 27704U 03010A   06293.11111694 -.00000035  0...
# 523  1 27704U 03010A   06291.11680023 -.00000037 +0...
#
#                                              tle_line2      residual  \
# 568  2 28129 054.6457 320.0220 0052136 264.7011 094...      2.667961
# 567  2 28129 054.6464 320.0627 0052109 264.7328 094...      2.685144
# 565  2 28129 054.6471 320.1034 0052084 264.7458 094...      2.798877
# 566  2 28129 054.6470 320.1034 0052057 264.7173 094...      3.076632
# 97   2 11690 063.8937 271.2930 0273259 182.2802 177...  13655.398480
# 95   2 11690 063.8947 271.3546 0272966 182.2597 177...  13655.433784
# 96   2 11690 063.8945 271.3237 0273183 182.2697 177...  13655.490270
# 64   2 10684 063.4960 271.4665 0061292 174.6670 185...  14799.212873
# 66   2 10684 063.4948 271.4050 0061264 174.7138 185...  14799.342119
# 67   2 10684 063.4948 271.4053 0061462 174.4244 185...  14800.350223
# 63   2 10684 063.4961 271.4673 0061451 174.3758 185...  14800.359758
# 65   2 10684 063.4956 271.4366 0061450 174.3827 185...  14800.381537
# 501  2 26605 056.5661 018.0814 0029663 239.6383 120...  18644.708753
# 502  2 26605 056.5665 018.0427 0029595 239.6489 120...  18644.913252
# 504  2 26605 056.5669 017.9849 0029655 239.4496 120...  18645.506308
# 503  2 26605 056.5665 018.0235 0029766 239.8189 119...  18645.562382
# 524  2 27704 053.9573 259.2051 0117859 194.4817 165...  26341.980232
# 526  2 27704 053.9567 259.1640 0117891 194.5129 165...  26342.162794
# 525  2 27704 053.9567 259.1641 0117886 194.5152 165...  26342.280045
# 523  2 27704 053.9576 259.2453 0117897 194.3381 165...  26342.820966
#
#      residual_epoch
# 568        1.014868
# 567        0.915504
# 565        0.941792
# 566        1.175188
# 97      1040.530089
# 95      1036.763553
# 96      1039.200601
# 64     10944.562958
# 66     10945.147727
# 67     10948.427374
# 63     10948.958294
# 65     10949.078937
# 501    14855.129969
# 502    14855.396853
# 504    14856.178753
# 503    14857.247391
# 524    26707.480312
# 526    26707.791902
# 525    26707.958536
# 523    26708.138379

# %%
sat = sat_gps[6]
candidate_sat = EarthSatellite(sat['TLE_LINE1'], sat['TLE_LINE2'], sat['TLE_LINE0'], ts)
candidate_sat.model.sgp4(jd, jdf)
# Out:
# (0,
#  (10668.296087647044, 7292.796722440949, -31842.335182255498),
#  (-2.501846359599823, 1.0696316015728493, 0.8648788164327018))

# %%
(np.ravel(solve_sat.model.sgp4(jd, jdf)[1:]) - np.ravel(candidate_sat.model.sgp4(jd, jdf)[1:]))[:3]
# Out:
# array([-20613.52012712, -18917.25585364,  10292.77859863])

# %%
solve_sat.model.sgp4_tsince(0)
# Out:
# (0,
#  (-9945.224039473405, -11624.459131194762, -21549.556583621394),
#  (2.9762057453190787, -2.509765457002418, -0.021943379755239682))

# %%
candidate_sat.model.sgp4_tsince((sat_epoch_datetime(solve_sat.model) - sat_epoch_datetime(candidate_sat.model)).total_seconds() / 60)
# Out:
# (0,
#  (10668.296167702032, 7292.796688214704, -31842.335209930596),
#  (-2.5018463562478765, 1.0696316038636393, 0.8648788064260986))

# %%
print(sat_epoch_datetime(solve_sat.model), sat_epoch_datetime(candidate_sat.model))
(sat_epoch_datetime(solve_sat.model) - sat_epoch_datetime(candidate_sat.model)).total_seconds()
# Out:
# 2006-10-19 02:44:46.999968+00:00 2006-10-20 17:18:13.250016+00:00
# -138806.250048

# %%
eph_is[0], t_is[0]
# Out:
# ((array([-20421.04220671,  16961.05759437,    -48.200446  ]),
#   array([-1.41399684, -1.74163053, -3.16097417])),
#  datetime.datetime(2006, 10, 15, 23, 59, 47, tzinfo=<UTC>))

# %%
candidate_sat.model.sgp4(*jday_datetime(t_is[0]))
# Out:
# (0,
#  (30657.74437934246, -6623.393156897523, -25793.922031972415),
#  (-0.8113843357046191, 1.142564036944282, -1.6191111000462464))

# %%
np.linalg.norm(np.ravel(eph_is[0])[:3] - np.ravel(candidate_sat.model.sgp4(*jday_datetime(t_is[0]))[1:])[:3])
# Out:
# 61871.72970205591

# %% [markdown]
# ## Calculate new TLE at same epoch as Reference / Truth TLE
#
# * Grab the the epoch from the reference (truth) TLE
# * Fit all ephemeris so epoch is in the sweet spot of the bathtub
#     * This is probably bullshit, since we wouldn't have the future ephemeris yet
# * Calculate the predicted state vector at the reference epoch using the fitted model
# * add the predicted state vector to our ephemeris
# * Re-fit up to the predicted state vector to get the mean elements for the reference epoch
# * Compare fitted TLE to reference TLE
#
# ### Notes
# * Probably better to interpolate ephemeris or use EKF to reference epoch

# %%
ref_tle = candidate_sat

# %%
sat_epoch_datetime(ref_tle.model)
# Out:
# datetime.datetime(2006, 10, 20, 17, 18, 13, 250016, tzinfo=UTC)

# %%
ajd, ajdf = jday_datetime(sat_epoch_datetime(ref_tle.model))

# %%
# We'll do the thinning outside so we can preserve the new epoch

if obs_stride:
    tt = t[::obs_stride]
    et = ephemeris[::obs_stride]

if last_obs:
    tt = tt[:last_obs]
    et = et[:last_obs]

aligned_epoch_obs = np.searchsorted(tt, sat_epoch_datetime(ref_tle.model))
# ii = np.searchsorted(t, sat_epoch_datetime(ref_tle.model))
tt = np.insert(t, aligned_epoch_obs, sat_epoch_datetime(ref_tle.model))
et = ephemeris[:aligned_epoch_obs] + [tuple(np.array(x) for x in ref_tle.model.sgp4(ajd, ajdf)[1:])] + ephemeris[aligned_epoch_obs:]

# %%
sat_epoch_datetime(ref_tle.model)
# Out:
# datetime.datetime(2006, 10, 20, 17, 18, 13, 250016, tzinfo=UTC)

# %%
tt[aligned_epoch_obs]
# Out:
# datetime.datetime(2006, 10, 20, 17, 18, 13, 250016, tzinfo=UTC)

# %%
iterations, aligned_solve_sat, elements_coe, sigma, sigmas, dxs, bs, lamdas, b_epoch, b_new_epoch, b, P, A = test_tle_fit_normalized_equinoctial(tt, et, last_obs=None, obs_stride=None, epoch_obs=aligned_epoch_obs, lamda=1e-3, rms_epsilon=0.0001, debug=False)

# %%
aligned_solve_sat.model.intldesg = ref_tle.model.intldesg
# aligned_solve_sat.model.satnum = ref_tle.model.satnum # FIXME: assign this in satrec at creation
aligned_solve_sat.model.classification = ref_tle.model.classification
# aligned_solve_sat.model.ndot = ref_tle.model.ndot # Useless, but pretty
# aligned_solve_sat.model.nddot = ref_tle.model.nddot# Useless, but pretty

exporter.export_tle(aligned_solve_sat.model)
# Out:
# ('1 99999U 72072A   06293.72098669  .00000000  00000-0 -10000+1 0  9992',
#  '2 99999  54.6451 320.0064 0052539 264.4272  85.1870  2.00562788    16')

# %%
exporter.export_tle(ref_tle.model)
# Out:
# ('1 06192U 72072A   06293.72098669  .00000791  00000-0  10000-3 0  9994',
#  '2 06192  69.9404 150.1133 5399813  47.6269 347.1851  2.01337587250640')

# %%
plt.plot(np.sqrt(solution_residuals(t, aligned_solve_sat.model, ref_tle.model)) * 1000)
plt.title("Solution vs. Candidate NORAD Object Residuals")
plt.xlabel("Observation number")
plt.ylabel("Position Residual (m)")
# Out:
# Text(0, 0.5, 'Position Residual (m)')
